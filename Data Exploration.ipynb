# %% [markdown]
# # Data Exploration, Visualization and Analysis
#
# - Wine dataset

# %% [markdown]
# ## Important packages for this task

# %%
# importing important packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import seaborn as sns

# %% [markdown]
# ## Loading Data
# In this part, we will load the data and start exploring the data

# %%
# Loading data
df = pd.read_csv('./datasets/winemag-data-130k-v2.csv')

# %%
df.shape
# Out:
# (129971, 14)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
# Exploring data
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0  country  \
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            92506 non-null   object
#  4   points                 129971 non-null  int64
#  5   price                  120975 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               108724 non-null  object
#  8   region_2               50511 non-null   object
#  9   taster_name            103727 non-null  object
#  10  taster_twitter_handle  98758 non-null   object
#  11  title                  129971 non-null  object
#  12  variety                129970 non-null  object
#  13  winery                 129971 non-null  object
# ...

# %%
# df.dropna().shape

# %%
df['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
countries = df['country'].value_counts()
countries
# Out:
# country
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
x = countries.index
y = countries.values
y
# Out:
# array([54504, 22093, 19540,  6645,  5691,  4472,  3800,  3345,  2329,
#         2165,  1419,  1401,   505,   466,   257,   146,   141,   120,
#          109,    90,    87,    86,    74,    73,    70,    59,    52,
#           35,    28,    16,    14,    12,    12,    12,    11,     9,
#            7,     6,     2,     2,     1,     1,     1])

# %%
plt.figure(figsize=(10,6))
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Countries')
plt.ylabel('Wine varieties')
plt.title('Wine Varieties in different countries')
plt.show()

# %% [markdown]
# ## Descriptive Statistics

# %%
df.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
df[['points', 'price']].dropna().corr()
# Out:
#           points     price
# points  1.000000  0.416167
# price   0.416167  1.000000

# %%
'''

Which varieties are the most expensive wines?
Which variteis are the cheapest ? 

'''
# Out:
# '\n\nWhich varieties are the most expensive wines?\nWhich variteis are the cheapest ? \n\n'

# %%
df.head()
# country, price, variety
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.sort_values(by = ['price'],ascending=False).iloc[0:10, 0:]
# Out:
#         Unnamed: 0 country                                        description  \
# 80290        80290  France  This ripe wine shows plenty of blackberry frui...
# 15840        15840  France  The wine is a velvet glove in an iron fist. Th...
# 98380        98380  France  A superb wine from a great year, this is power...
# 120391      120391      US  The nose on this single-vineyard wine from a s...
# 113564      113564  France  A wonderfully complete wine, with all the elem...
# 65352        65352  France  This extravagantly perfumed wine has great jui...
# 1558          1558  France  A massive wine for Margaux, packed with tannin...
# 111753      111753  France  Almost black in color, this stunning wine is g...
# 111755      111755  France  This is the finest Cheval Blanc for many years...
# 1575          1575  France  The purest Cabernet Sauvignon fruit, with dark...
#
#                 designation  points   price    province       region_1  \
# ...

# %%
sorted_df = df.sort_values(by = ['price'],ascending=False).iloc[0:25, 0:]
sorted_df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
sorted_df[['country','price','points','variety']]
# Out:
#           country   price  points                     variety
# 80290      France  3300.0      88    Bordeaux-style Red Blend
# 15840      France  2500.0      96    Bordeaux-style Red Blend
# 98380      France  2500.0      96                  Pinot Noir
# 120391         US  2013.0      91                  Chardonnay
# 113564     France  2000.0      96                  Pinot Noir
# 65352      France  2000.0      97    Bordeaux-style Red Blend
# 1558       France  1900.0      98    Bordeaux-style Red Blend
# 111753     France  1500.0     100    Bordeaux-style Red Blend
# 111755     France  1500.0     100    Bordeaux-style Red Blend
# 1575       France  1300.0      96    Bordeaux-style Red Blend
# 1571       France  1200.0      96    Bordeaux-style Red Blend
# 113581     France  1125.0      94                  Pinot Noir
# 1566       France  1100.0      97    Bordeaux-style Red Blend
# 89478     Austria  1100.0      94            Grüner Veltliner
# ...

# %%
sorted_df = df.sort_values(by = ['price'],ascending=True, na_position='last').iloc[0:25, 0:]
sorted_df[['country','price','points', 'variety']]
# Out:
#           country  price  points                    variety
# 20484          US    4.0      85                White Blend
# 112919      Spain    4.0      84                Tempranillo
# 59507          US    4.0      83                 Chardonnay
# 31530          US    4.0      84                 Chardonnay
# 61768       Spain    4.0      84         Cabernet Sauvignon
# 1987        Spain    4.0      85                      Syrah
# 126096    Romania    4.0      86               Pinot Grigio
# 64590          US    4.0      86                     Merlot
# 117303      Spain    4.0      82                White Blend
# 29553   Argentina    4.0      84               Malbec-Syrah
# 110255         US    4.0      84                     Merlot
# 125826  Argentina    5.0      80                     Malbec
# 49624    Portugal    5.0      82           Portuguese White
# 33381       Spain    5.0      81                Tempranillo
# 105918     France    5.0      83                 Pinot Noir
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df['winery'].value_counts()
# Out:
# winery
# Wines & Winemakers    222
# Testarossa            218
# DFJ Vinhos            215
# Williams Selyem       211
# Louis Latour          199
#                      ...
# Hypothesis              1
# Camps d'Estels          1
# Harbor Town             1
# Château de Saurs        1
# Penedo Borges           1
# Name: count, Length: 16757, dtype: int64

# %%
df[['country','title','description', 'taster_name', 'points','price','variety','winery']].to_csv('./datasets/cleaned-wine.csv')

# %%
df['province'].value_counts()
# Out:
# province
# California        36247
# Washington         8639
# Bordeaux           5941
# Tuscany            5897
# Oregon             5373
#                   ...
# Messinia              1
# Markopoulo            1
# Paardeberg            1
# Krania Olympus        1
# Neuchâtel             1
# Name: count, Length: 425, dtype: int64

# %%
df.shape
# Out:
# (129971, 14)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (129971, 14)

# %%
df['country'].value_counts()[:15].plot(kind = 'bar')
plt.show()

# %%
tastes = ['Fruity', 'Earthy', 'Spicy', 'Smoky','Flowery', 'Acidic']
for desc in df['description']:
    if 'Earthy' in desc:
        print(desc)
# Out:
# Earthy pollen and mineral notes lend a savory tone to this medium-sweet Riesling. It's soft and slightly pulpy, intensified by overripe tangerine and stone fruit flavors. Drink now through 2018.
# Earthy, savory notes of yeast and miso swing alongside the green pear flavors. There is spice and concentration on the midpalate and some tingling pepper spice.
# Winemaker Dennis Martin puts grape grower Stephen Miller's signature on this wine, a nod to the importance of this historic vineyard. The wine shows bright strawberry and raspberry with touch of savory wood smoke as well as hibiscus-laced pastry and a pinch of thyme. Earthy sagebrush and wild herb flavors frame the palate, where cooked cherries and cranberries are spiced by cardamom and dried ginger spice.
# ...

# %%
"""
# ETL
# Fetched
# Transformation
# Inject to database => MySQL or Mongod
# Fetch?


# Data come from databases.
# We will store data in databaes.
It is good to know to work with databases.
- You know how to fetch data from API
- You know how to extract, clean and transform the data
- You know to inject or store the data in a database
- You know how to fetch from databases


"""
# Out:
# '\n# ETL\n# Fetched\n# Transformation\n# Inject to database => MySQL or Mongod\n# Fetch?\n\n\n# Data come from databases.\n# We will store data in databaes.\nIt is good to know to work with databases.\n- You know how to fetch data from API\n- You know how to extract, clean and transform the data\n- You know to inject or store the data in a database\n- You know how to fetch from databases\n\n\n'
